# %% [markdown]
# ## Real-World Assignment

# %% [markdown]
# 1. The Smart Attendance Logger
# - The Goal: Manage a classroom attendance list and ensure no duplicate entries are recorded if a student taps their ID card twice.
# - Concepts: set , function , while .
# - The Problem: Create a function mark_attendance() that keeps asking for student names until the user types "STOP". Store names in a Set to automatically prevent duplicates.
# - Input: Multiple strings (names) entered one by one.
# - Output: The final count of unique students and the set itself.
# - Hint: Expected Flow: Start an empty set Use a while True loop to take input() if name is "STOP", break else add name to set Finally, print len(attendance_set) .

# %%
def mark_attendance():
    global attendance_set
    attendance_set = set() 
    
    while True:
        name = input("Enter student name (or type 'STOP' to finish): ").strip()
        if name.upper() == "STOP":
            break
        elif name:
            attendance_set.add(name.title())
            print(attendance_set)

mark_attendance()
print(attendance_set)

print("\n--- Attendance Report ---")
print("Total Unique Students: ",len(attendance_set))
print("Attendees: ",', '.join(attendance_set))
# Out:
# {'Ankit'}
# {'Ankit'}
# {'Dinesh', 'Ankit'}
# {'Dinesh', 'Ankit'}
# {'Rohit', 'Dinesh', 'Ankit'}
# {'Ravi', 'Rohit', 'Dinesh', 'Ankit'}
# {'Ravi', 'Rohit', 'Dinesh', 'Ankit'}
# {'Ankit', 'Nikhil', 'Ravi', 'Rohit', 'Dinesh'}
# {'Ankit', 'Nikhil', 'Ravi', 'Rohit', 'Dinesh'}
# {'Ankit', 'Nikhil', 'Ravi', 'Rohit', 'Dinesh'}
#
# --- Attendance Report ---
# Total Unique Students:  5
# Attendees:  Ankit, Nikhil, Ravi, Rohit, Dinesh

# %% [markdown]
# 2. The Restaurant Bill Splitter
# - The Goal: Calculate how much each person owes, including a tax and a custom tip percentage.
# - Concepts: functions , default values , list .
# - The Problem: Write a function split_bill(items_prices, people, tax=0.05, tip=0.10) . items_prices will be a List of decimals (floats).
# - Input: A list like [25.0, 15.0, 10.0] and an integer for people .
# - Output: A single float (the amount per person).
# - Hint: Expected Flow: Calculate sum() of the list Add tax and tip amounts Divide the grand total by people return the result.

# %%
def split_bill(items_prices, people, tax=0.05, tip=0.10):
    total_price = sum(items_prices)
    total_price_with_tax_tip = total_price * (1 + tax + tip)
    per_person_cost = round(total_price_with_tax_tip / people,2)
    return per_person_cost

items_prices = [47.5, 18.0, 10.5]
people = 4
per_person_cost = split_bill(items_prices , people)
print("The amount per person : $",per_person_cost)
# Out:
# The amount per person : $ 21.85

# %% [markdown]
# 3. The Digital Wardrobe Organizer
# - The Goal: Check if a specific outfit is available or if parts of it are missing.
# - Concepts: multiple if , list , input .
# - The Problem: You have a list wardrobe = ["Blue Jeans", "White Shirt", "Black Jacket"] . Ask the user for 3 items they want to wear. Check each item individually against the list.
# - Input: Three separate input() strings (e.g., "Red Tie", "White Shirt", "Socks").
# - Output: A "Missing" warning for every item not found in the list.
# - Hint: Expected Flow: Take 3 inputs Use three separate if statements (not elif ) to check if each input is not in the wardrobe list Print "Missing [Item]" for each failure.

# %%
wardrobe = ["Blue Jeans", "White Shirt", "Black Jacket"]
item_1 = input("Enter the first item : ").title()
item_2 = input("Enter the second item : ").title()
item_3 = input("Enter the third item : ").title()

if item_1 in wardrobe:
    pass
else:
    print("Missing", item_1)
if item_2 in wardrobe:
    pass
else:
    print("Missing", item_2)
if item_3 in wardrobe:
    pass
else:
    print("Missing", item_3)
# Out:
# Missing Black Jeans
# Missing Tie

# %% [markdown]
# #### 2nd method

# %%
wardrobe = ["Blue Jeans", "White Shirt", "Black Jacket"]
item_1 = input("Enter the first item : ").strip().title()
item_2 = input("Enter the second item : ").strip().title()
item_3 = input("Enter the third item : ").strip().title()

if item_1 not in wardrobe:
    print("Warning :", item_1,"not found")
if item_2 not in wardrobe:
    print("Warning :", item_2,"not found")
if item_3 not in wardrobe:
    print("Warning :", item_3,"not found")

# %% [markdown]
# 4. The E-Commerce Discount Engine
# - The Goal: Apply different discount rates based on the total purchase amount.
# - Concepts: if-elif-else , functions .
# - The Problem: Create a function apply_discount(total) .
# - If total > $500: 20% off.
# - If total > $200: 10% off.
# - Else: No discount.
# - Input: A single number (the total bill).
# - Output: The final price after the discount is subtracted.
# - Hint: Expected Flow: Receive the total Use an if-elif-else chain to determine the discount percentage Calculate the new price return it.

# %%
def apply_discount(total):
    if total > 500:
        discount_rate = 0.2
    elif total > 200:
        discount_rate = 0.1
    else:
        discount_rate = 0
    
    new_price = total * (1 - discount_rate)
    return round(new_price,2)

total_bill = float(input("Enter the total bill : "))
final_price_after_discount = apply_discount(total_bill)
print("Final price :",final_price_after_discount)
# Out:
# Final price : 440.0

# %% [markdown]
# 5. The Contact Book Search
# - The Goal: Look up a phone number using a person's name.
# - Concepts: dict , input , if-else .
# - The Problem: Create a Dictionary of 5 friends (Name: Number). Ask the user for a name to search.
# - Input: A string (Name).
# - Output: The phone number if found, or "Contact not found".
# - Hint: Expected Flow: Define the dict Get input() Use if name in phonebook: to check for the key Print the value (number) or the error message.

# %%
contact_details = {
        "Ankit" : 8754236589,
        "Dinesh" : 5246389759,
        "Rohit": 9756842365,
        "Ravi" : 7854698245,
        "Nikhil" : 3654789654}
contact = input("Enter the name of contact : ").strip().title()
if contact in contact_details:
    print("Found : The contact number of",contact,"is :",contact_details[contact])
else:
    print("Error : Contact not found")
# Out:
# Found : The contact number of Ankit is : 8754236589

# %% [markdown]
# 6. The Travel Itinerary Builder
# - The Goal: Print a numbered list of travel destinations for a user.
# - Concepts: for loop, list , enumerate .
# - The Problem: Given a list cities = ["Tokyo", "Paris", "New York", "London"] , print them as a
# numbered list.
# - Input: None (Uses the hardcoded list).
# - Output: A vertically formatted list (e.g., "1. Tokyo").
# - Hint: Expected Flow: Use a for loop with enumerate(cities, start=1) Print the index and the city name on the same line.

# %%
cities = ["Tokyo", "Paris", "New York", "London"]
print("---Travel destination---")
for i, num in enumerate(cities,start = 1):
    print(str(i) + ".", num)
# Out:
# ---Travel destination---
# 1. Tokyo
# 2. Paris
# 3. New York
# 4. London

# %% [markdown]
# #### 2nd method

# %%
cities = ["Tokyo", "Paris", "New York", "London"]
print("---Travel destination---")
for i, num in enumerate(cities,start = 1):
    print(f"{i}. {num}")
# Out:
# ---Travel destination---
# 1. Tokyo
# 2. Paris
# 3. New York
# 4. London

# %% [markdown]
# 7. The ATM Pin Validator
# - The Goal: Lock the user out after 3 incorrect attempts.
# - Concepts: while , if-else , break .
# - The Problem: Set correct_pin = "1234" . Allow the user 3 tries to enter the right PIN.
# - Input: Up to 3 string inputs.
# - Output: "Welcome" on success, or "Card Blocked" after the 3rd fail.
# - Hint: Expected Flow: Set attempts = 0 While attempts < 3 : Take PIN input if correct, print "Welcome" and break else increment attempts . If attempts reaches 3, print "Card Blocked."

# %%
attempts = 0
correct_pin = "1234"
while attempts < 3:
    input_pin = input(f"Enter the ATM pin ({3 - attempts} attempts left) :")
    if input_pin == correct_pin:
        print("Access Granted : Welcome back!")
        break
    else:
        attempts += 1
    if attempts == 3:
        print("Error message : Card Blocked. Please contact your bank")
# Out:
# Error message : Card Blocked. Please contact your bank

# %% [markdown]
# #### 2nd method

# %%
attempts = 0
correct_pin = "1234"
while attempts < 3:
    input_pin = input("Enter the ATM pin (" + str(3 - attempts) + " attempts left) :")
    if input_pin == correct_pin:
        print("Access Granted : Welcome back!")
        break
    else:
        attempts += 1
    if attempts == 3:
        print("Error message : Card Blocked. Please contact your bank")
# Out:
# Error message : Card Blocked. Please contact your bank

# %% [markdown]
# 8. The Movie Ticket Age Checker
# - The Goal: Categorize a movie-goer and assign a price.
# - Concepts: tuple , if-elif-else .
# - The Problem: Use a Tuple to store fixed prices: PRICES = (0, 10, 15) (Free, Child, Adult). Ask for age and determine which index from the tuple to use.
# - Input: An integer (Age).
# - Output: The price fetched from the tuple.
# - Hint: Expected Flow: Get age Use if-elif-else to decide the index (0, 1, or 2) Print the value from PRICES[index] .

# %%
prices = (0, 10, 15)    # Price for free, child, adult
age = int(input("Enter the age of the customer"))

if age < 5:
    price = prices[0] 
elif age < 10:
    price = prices[1]
else:
    price = prices[2]

print("Cost of ticket is $ " + str(price) + ".")
# Out:
# Cost of ticket is $ 15.

# %%
prices = (0, 10, 15)    # Price for free, child, adult
age = int(input("Enter the age of the customer"))

if age < 5:
    price = prices[0] 
elif age < 10:
    price = prices[1]
else:
    price = prices[2]

print(f"Cost of ticket is $ {str(price)}.")
# Out:
# Cost of ticket is $ 15.

# %% [markdown]
# 9. The Grocery Inventory Update
# - The Goal: Update the quantity of items in a store after a shipment arrives.
# - Concepts: dict , for loop.
# - The Problem: Given inventory = {"Apples": 50, "Bananas": 20} , a shipment of 10 more of each
# arrives. Update the dictionary using a loop.
# - Input: None.
# - Output: The updated dictionary.
# - Hint: Expected Flow: Loop through inventory.keys() For each item, add 10 to the current value Print the dictionary after the loop finishes.

# %%
inventory = {"Apples": 50, "Bananas": 20}
for item in inventory.keys():
    inventory[item] += 10

print(inventory)
# Out:
# {'Apples': 60, 'Bananas': 30}

# %%
inventory = {"Apples": 50, "Bananas": 20}
for item in inventory.keys():
    inventory[item] += 10

print(f"---Updated Grocery Inventory---")
for fruit, stocks in inventory.items():
    print(f"{fruit} : {stocks} units")
# Out:
# ---Updated Grocery Inventory---
# Apples : 60 units
# Bananas : 30 units

# %% [markdown]
# 10. The Flexible Event Invitation
# - The Goal: Create a function that can accept any number of guests and specific event details.
# - Concepts: functions , *args , **kwargs .
# - The Problem: Write create_invite(event_name, *guest_names, **details) .
# - Input: One string, followed by multiple guest names, followed by named details (e.g.,
# - Output: A printed invitation showing the event, guests, and details.
# - Hint: Expected Flow: Print the event_name Use a loop through **details (extra info) and print them.

# %%
def create_invite(event_name, *guest_names, **details):
    print(f"\n---{event_name.upper()}---")
    print("Guest List : ")
    for guest in guest_names:
        print(f"{guest}")
    
    print("\nEvent Details : ")
    for key, value in details.items():
        print(f"{key.replace("_", " ").title()} : {value}")

create_invite("Marriage function", "Dinesh", "Rohit", "Atharv", Date = "18/02/1965", 
              start_Time = "6 pm", Location = "Jhansi")
# Out:
# ---MARRIAGE FUNCTION---
# Guest List :
# Dinesh
# Rohit
# Atharv
#
# Event Details :
# Date : 18/02/1965
# Start Time : 6 pm
# Location : Jhansi

# %%
def create_invite(event_name, *guest_names, **details):
    print(f"\n---{event_name.upper()}---")
    print("Guest List : ")
    for guest in guest_names:
        print(f"{guest}")
    
    print("\nEvent Details : ")
    for key, value in details.items():
        print(f"{key.replace("_", " ").title()} : {value}")

create_invite("50th Anniversary function Invitation", "Dinesh", "Rohit", "Atharv", Date = "18/02/1965", 
              start_Time = "6 pm", Location = "Jhansi")
# Out:
# ---50TH ANNIVERSARY FUNCTION INVITATION---
# Guest List :
# Dinesh
# Rohit
# Atharv
#
# Event Details :
# Date : 18/02/1965
# Start Time : 6 pm
# Location : Jhansi
